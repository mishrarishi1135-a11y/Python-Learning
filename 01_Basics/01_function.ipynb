# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Anuj Mishra\OneDrive\Desktop\Projects\Python Learning\.venv\Scripts\python.exe

# %%
# In Python, we have a built function that is "print".
print("Hello World")
# Out:
# Hello World

# %%
print(6) # Integer
# Out:
# 6

# %%
print(1.6) # Float
# Out:
# 1.6

# %%
print(False) # BOolean
# Out:
# False

# %%
print("India","Pakistan","USA","Japan")  # This space is come through 'sep' parameter.
# Out:
# India Pakistan USA Japan

# %%
# Print different data types at one time
print("India", 5, True)
# Out:
# India 5 True

# %%
# You write much more values with the help of commas inside the print() Function.
print("India","Pakistan","USA","Japan",sep='/')
# Out:
# India/Pakistan/USA/Japan

# %%
print("India","Pakistan","USA","Japan",sep='-')
# Out:
# India-Pakistan-USA-Japan

# %%
# end parameter: /n that means Line change
print("hello")
print("world")
# Out:
# hello
# world

# %%
# If you want to print in one line
print("hello",end=' ')
print("world")
# Out:
# hello world
