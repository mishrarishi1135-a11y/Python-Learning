# %%
# Operators --> are used to perform operations on variables and values.

# arithmetic operator
x = 5
y = 10
print(x + y)
# Out:
# 15

# %%
print(x - y)
# Out:
# -5

# %%
print(x%y)
# Out:
# 5

# %%
print(x**y)
# Out:
# 9765625

# %%
print(x*y)
# Out:
# 50

# %%
print(x//y)  # integer division
# Out:
# 0

# %%
print(x/y)  # true division
# Out:
# 0.5

# %%
# Comparison operator
print(x>y)
# Out:
# False

# %%
print(x<y)
# Out:
# True

# %%
print(x>=y)
# Out:
# False

# %%
print(x == y)
# Out:
# False

# %%
print(x != y)
# Out:
# True

# %%
# Logical operator
x = True
y = False
print(x or y)
# Out:
# True

# %%
print(x and y)
# Out:
# False

# %%
print(not y)
# Out:
# True

# %%
# Bitwise operator - works on binary values
x = 2  # apply binary pattern
y = 3
print(x & y)
# Out:
# 2

# %%
print(x | y)
# Out:
# 3

# %%
print( x >> 2)   # right shift
# Out:
# 0

# %%
print(y << 3)  # left shift
# Out:
# 24

# %%
print(~3)
# Out:
# -4

# %%
# Assignment operator
a = "anuj"
print(a)
# Out:
# anuj

# %%
a = 3
a += 3
print(a)
# Out:
# 6

# %%
a *= 3
print(a)
# Out:
# 18

# %%
# In python, these will not work a++ , ++a  ( invalid syntax)
# Identity operators - check any two variables are in same memory location
a = 3
b = 3
print(a is b)   # so a and b are identical.
# Out:
# True

# %%
a = [1,2,3,4]
b = [1,2,3,4]
print(a is b)  # also both are same but not store in same memory location so gives false.
# Out:
# False

# %%
a = "Hello-World"
b = "Hello-World"
print(a is b)  # Both are stored in different location.
# Out:
# False

# %%
# membership operator : check this value is inside it or not.
x = 'Delhi'
print('D' in x)
# Out:
# True

# %%
print('e' not in x)
# Out:
# False

# %%
# If-else statement or decision control statement
email = input("Enter your email")
password = input("Enter your password")
# Correct email - anuj@123 and password is - 1234
if email == "anuj@123" and password == "1234":
    print("welcome")
else:
    print("incorrect credentials")
# Out:
# welcome

# %%
# Now you want if a user give correct email but wrong password then we gave a one more chance to the user for asking password.
# if , else-if(elif in python), else
email = input("Enter your email")
password = input("Enter your password")
# Correct email - anuj@123 and password is - 1234
if email == "anuj@123" and password == "1234":
    print("welcome")
elif email == "anuj@123" and password != "1234":
    print("password incorrect")
    password = input("again give correct password")
    # Now use nested elif
    if password == "1234":
        print("finally correct")
    else:
        print("still incorrect")
else:
    print("incorrect credentials")
# Out:
# password incorrect
# finally correct
