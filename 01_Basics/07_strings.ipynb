# %%
# By using c language we can create only system software like it can only talk with hardware not with user.
# that is why, In c language strings are not present as a data type.
# string --> sequence of characters.(In python, they are sequence of unicode characters) and it only understand binary.
# Character convert into the ASCII value then convert into Binary value then python understand your query/order.

# %%
# Creating strings
c = 'Hello'
print(c)
# Out:
# Hello

# %%
d = " It's raining outside"   # safe from error.
print(d)
# Out:
#  It's raining outside

# %%
# Multi line string: blog type, article type
c = """"Hello, this is the python learning repository. I think you prefer this for increase your knowledge."""
print(c)
# Out:
# "Hello, this is the python learning repository. I think you prefer this for increase your knowledge.

# %%
c = str("Anuj")
c
# Out:
# 'Anuj'

# %%
# Accessing substrings from a string

# Concept of indexing: every character have it's own index position.
c = "Rahul"
print(c[2])
# Out:
# h

# %%
print(c[9])  # gives error, string index out of range.

# %%
# Types of indexing --> positive and negative indexing
a = "Woxson"
print(a[-4])
# Out:
# x

# %%
# The concept of slicing --> for extract multiple characters
a = "do not play all the time."
print(a[2:8])     # last 8 is not included -(include,exclude)
# Out:
#  not p

# %%
print(a[3:])
# Out:
# not play all the time.

# %%
# Reverse the string
print(a[::-1])
# Out:
# .emit eht lla yalp ton od

# %%
# We can also give step for skipping the values.
print(a[2:14:2])
# Out:
#  o lya

# %%
# editing and deleting strings
# String object does not support item assignment.

c = "Hello"
print(c)
# Out:
# Hello

# %%
# Now if we edit the string.
c[0] = "X"   # It show the error.
# In python, strings are immutable data type, we can't edit the string and also you can't add further elements in given string.

# %%
# Deletion
del c  # Actual me deletion nhi hota hai.

# %%
del c[0]    # In string, changes are not allowed.you can delete completely not partially.

# %%
# Operations on strings --> arithmetic, logical, relational, loops on string, membership operations.
"hello" + "world"  # string concatenation
# Out:
# 'helloworld'

# %%
# string multiplication
print("*"*50)
# Out:
# **************************************************

# %%
# in string, comparison is done through the ASCII value.(Lexiographically)
"Delhi" > "Kanpur"
# Out:
# False

# %%
# empty string --> false
# non-empty string --> true
"hello" and "world"
# Out:
# 'world'

# %%
"" and "Earn"
# Out:
# ''

# %%
"" or "world"
# Out:
# 'world'

# %%
# Loops on strings
c = "earn money"
for i in c:
    print(i)
# Out:
# e
# a
# r
# n
#
# m
# o
# n
# e
# y

# %%
for i in c[2:4]:
    print(i)
# Out:
# r
# n

# %%
# Membership operator
c = "Hello World"
print(c)
# Out:
# Hello World

# %%
"h" in c
# Out:
# False

# %%
"e" in c
# Out:
# True

# %%
# String Functions in python
# Common function --> len, max, min, sorted
c = "kolakta"
len(c)
# Out:
# 7

# %%
max(c)  # based on the ASCII value
# Out:
# 't'

# %%
# sorting based on the ASCII value in ascending order in list form
sorted(c)
# Out:
# ['a', 'a', 'k', 'k', 'l', 'o', 't']

# %%
# If you want in descending order then use reverse parameter
sorted(c,reverse=True)
# Out:
# ['t', 'o', 'l', 'k', 'k', 'a', 'a']

# %%
# Capitalize/Title/Upper/Lower/swapcase
c
# Out:
# 'kolakta'

# %%
c.capitalize()   # capital the first letter, but will not change the original string.
# Out:
# 'Kolakta'

# %%
c.title()   # capital every word's first letter.(like in title case)
# Out:
# 'Kolakta'

# %%
c.upper()
# Out:
# 'KOLAKTA'

# %%
c.lower()
# Out:
# 'kolakta'

# %%
# swapcase --> convert lower into upper and vice-versa.
"ANuj".swapcase()
# Out:
# 'anUJ'

# %%
# Count function: gives the count of any string
"It is raining".count("i")  # It works on also substring.
# Out:
# 3

# %%
# Find function --> gives the index of asked value or character.(tell the first occurence)
"It is raining".find("g")
# It gives (-1) if it's not present in string whatever you ask.
# Out:
# 12

# %%
# Index function --> almost same
# But here if we have value which is not find in string so it show error.all the entire work will same.
"It is raining".index("i")
# Out:
# 3

# %%
# endswith / startswith
"It is raining".endswith("eing")
# Out:
# False

# %%
"It is raining".startswith("It")
# Out:
# True

# %%
# Format
"Hello my name is {} and I am {}".format("Anuj",19)
# Out:
# 'Hello my name is Anuj and I am 19'

# %%
# In Bracket, we can also give position.
"hello my name is {1} and I am {0}".format("Anuj",19)
# Out:
# 'hello my name is 19 and I am Anuj'

# %%
# We also send a value in a parameter like variables.
"Hello my name is {Name} and I am {age}".format(Name="Anuj",age=19)
# Out:
# 'Hello my name is Anuj and I am 19'

# %%
# isalnum / isalpha / isdecimal / isdigit / isidentifier
"FLAT20".isalnum()      # It check all the values are alphanumeric or not
# Out:
# True

# %%
"ANU@#$".isalnum()    # here we use some special character
# Out:
# False

# %%
# check all are alphabet
"FLAT".isalpha()
# Out:
# True

# %%
"20A".isdigit()
# Out:
# False

# %%
"Hello world".isidentifier()
# Out:
# False

# %%
# But if we use the underscore(_) so it is a valid identifier.
"Hello_world".isidentifier()
# Out:
# True

# %%
# Split function --> it create a list from a given string.
"Who is prime minister of India".split()
# Out:
# ['Who', 'is', 'prime', 'minister', 'of', 'India']

# %%
# If you want to single element in list
"Who is prime minister of India".split("X")
# Out:
# ['Who is prime minister of India']

# %%
# Join function -- The reverse of split()
" ".join(['Who', 'is', 'prime', 'minister', 'of', 'India'])
# Out:
# 'Who is prime minister of India'

# %%
"/".join(['Who', 'is', 'prime', 'minister', 'of', 'India'])
# Out:
# 'Who/is/prime/minister/of/India'

# %%
# Replace()
"Hi my name is Rahul".replace("Rahul","Anuj")    # (wht's you replace,what you put on that point)
# Out:
# 'Hi my name is Anuj'

# %%
# Strip -- extra spaces and trailing words removed
name ="                        Anuj        "
name.strip()
# Out:
# 'Anuj'
